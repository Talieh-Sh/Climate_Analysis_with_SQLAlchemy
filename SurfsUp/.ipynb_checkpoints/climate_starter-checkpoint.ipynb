# %%
# %matplotlib inline
from matplotlib import style
style.use('fivethirtyeight')
import matplotlib.pyplot as plt

# %%
import numpy as np
import pandas as pd
import datetime as dt
from datetime import datetime, timedelta

# %% [markdown]
# # Reflect Tables into SQLAlchemy ORM

# %%
# Python SQL toolkit and Object Relational Mapper
import sqlalchemy
from sqlalchemy.ext.automap import automap_base
from sqlalchemy.orm import Session
from sqlalchemy import create_engine, func,  inspect

# %%
# create engine to hawaii.sqlite
engine = create_engine("sqlite:///../Resources/hawaii.sqlite")

# %%
# reflect an existing database into a new model

Base=automap_base()

# reflect the tables
Base.prepare(autoload_with=engine)

# %%
# View all of the classes that automap found
Base.classes.keys()
# Out:
# ['measurement', 'station']

# %%
# Save references to each table
Measurement=Base.classes.measurement
Station=Base.classes.station

# %%
# Create our session (link) from Python to the DB
session=Session(engine)

# %%
# Fetching the first row of measurement table
first_row = session.query(Measurement).first()
first_row.__dict__
# Out:
# {'_sa_instance_state': <sqlalchemy.orm.state.InstanceState at 0x7f80ca3effd0>,
#  'station': 'USC00519397',
#  'prcp': 2.0,
#  'id': 0,
#  'date': '2010-01-01',
#  'tobs': 18.3}

# %%
# Fetching the first row of Station table
first_row = session.query(Station).first()
first_row.__dict__
# Out:
# {'_sa_instance_state': <sqlalchemy.orm.state.InstanceState at 0x7f80a82dd050>,
#  'station': 'USC00519397',
#  'latitude': 21.2716,
#  'elevation': 0.914,
#  'id': 0,
#  'name': 'WAIKIKI 717.2, HI US',
#  'longitude': -157.8168}

# %% [markdown]
# # Exploratory Precipitation Analysis

# %%
# Find the most recent date in the data set.
recent_date=session.query(Measurement).group_by(Measurement.date).order_by(Measurement.date.desc()).first()
print(recent_date.date)
#print(type(recent_date.date))
# Out:
# 2017-08-23

# %%
last_date_string=recent_date.date

# Convert the last date string to a date object
last_date=datetime.strptime(last_date_string,"%Y-%m-%d").date()

# Calculate one year from the last date
one_year_ago=last_date-timedelta(days=365)

print(one_year_ago)
# Out:
# 2016-08-23

# %%
# Design a query to retrieve the last 12 months of precipitation data and plot the results. 
# Starting from the most recent data point in the database. 
last_date=datetime.strptime(last_date_string,"%Y-%m-%d").date()

# Calculate the date one year from the last date in data set.
one_year_ago=last_date-timedelta(days=365)



# Perform a query to retrieve the data and precipitation scores
# results = session.query(Measurement.date, func.max(Measurement.prcp))\
#                  .filter(Measurement.date >= one_year_ago)\
#                  .group_by(Measurement.date)\
#                  .all()


#Perform a query to retrieve the data and precipitation scores
results = session.query(Measurement.date, Measurement.prcp)\
                 .filter(Measurement.date >= one_year_ago, Measurement.prcp.isnot(None)).all()




# Save the query results as a Pandas DataFrame and set column names
df = pd.DataFrame(results, columns=['Date', 'Precipitation'])
print(df)
# Sort the dataframe by date
df = df.sort_values('Date')

# Use Pandas Plotting with Matplotlib to plot the data
plt.figure(figsize=(6, 5))
plt.bar(df['Date'], df['Precipitation'], width=4, color='blue', linewidth=1)
plt.xlabel('Date')
plt.ylabel('Precipitation (mm)')

# Set x-axis ticks to display only 5 dates
date_count = len(df)
step = max(date_count // 5, 1)
plt.xticks(df['Date'][::step], rotation=90)

plt.grid(axis='y', linestyle='--')

plt.legend(['Precipitation'], loc='upper center')
plt.tight_layout()

# Show the plot with 'fivethirtyeight' style
style.use('fivethirtyeight')
plt.show()
# Out:
#             Date  Precipitation
# 0     2016-08-23            0.0
# 1     2016-08-24            2.0
# 2     2016-08-25            2.0
# 3     2016-08-26            0.0
# 4     2016-08-27            0.0
# ...          ...            ...
# 2016  2017-08-17            3.3
# 2017  2017-08-19            2.3
# 2018  2017-08-21           14.2
# 2019  2017-08-22           12.7
# 2020  2017-08-23           11.4
#
# [2021 rows x 2 columns]

# %%
# Use Pandas to calculate the summary statistics for the precipitation data
df.describe()
# Out:
#        Precipitation
# count    2021.000000
# mean        4.505888
# std        11.713487
# min         0.000000
# 25%         0.000000
# 50%         0.500000
# 75%         3.300000
# max       170.200000

# %% [markdown]
# # Exploratory Station Analysis

# %%
# Design a query to calculate the total number of stations in the dataset
result_station=session.query(Measurement).group_by(Measurement.station).count()
result_station
# Out:
# 9

# %%
# Design a query to find the most active stations (i.e. which stations have the most rows?)
# List the stations and their counts in descending order.
station_activity=session.query(Measurement.station,func.count(Measurement.id)).\
group_by(Measurement.station).\
order_by(func.count(Measurement.id).desc()).all()
station_activity
# Out:
# [('USC00519281', 2772),
#  ('USC00519397', 2724),
#  ('USC00513117', 2709),
#  ('USC00519523', 2669),
#  ('USC00516128', 2612),
#  ('USC00514830', 2202),
#  ('USC00511918', 1979),
#  ('USC00517948', 1372),
#  ('USC00518838', 511)]

# %%
# Using the most active station id from the previous query, calculate the lowest, highest, and average temperature.

most_active_station=station_activity[0][0]
most_active_station
most_active_data=session.query(func.min(Measurement.tobs),func.max(Measurement.tobs),func.avg(Measurement.tobs)).\
filter(Measurement.station==most_active_station).group_by(Measurement.station).all()
most_active_data
# Out:
# [(12.2, 29.4, 22.03582251082252)]

# %%
active_station_results=session.query(Measurement.tobs).\
filter(Measurement.station==most_active_station,Measurement.date>=one_year_ago).all()
df=pd.DataFrame(active_station_results,columns=["tobs"])
df

# active_station_results = session.query(Measurement.tobs)\
#     .filter(Measurement.station == most_active_station)\
#     .filter(Measurement.date >= one_year_ago)\
#     .all()

# # Create a DataFrame from the query results
# df = pd.DataFrame(active_station_results, columns=["tobs"])
# df
# Plot the results as a histogram
plt.figure(figsize=(6, 5))
plt.hist(df["tobs"], bins=12)
plt.xlabel("Temperature (°F)")
plt.ylabel("Frequency")
#plt.title(f"Temperature Observation Data for Station {most_active_station}\nLast 12 Months")
plt.grid(axis="y", linestyle="--", alpha=0.7)
plt.tight_layout()
plt.show()

# %% [markdown]
# # Close Session

# %%
# Close Session
session.close()
